# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # data in a vectorized manner manipulation
import pandas as pd # data analsysis
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
from matplotlib import pyplot
import matplotlib as plt

# mlp with scaled outputs on the regression problem
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
from matplotlib import pyplot

# %%
data_sain = pd.read_csv('/content/drive/My Drive/PFE/dataSain2.csv')
def_a = pd.read_csv('/content/drive/My Drive/PFE/dataDéfA.csv')
def_t = pd.read_csv('/content/drive/My Drive/PFE/dataDéfT.csv')
def_v1 = pd.read_csv('/content/drive/My Drive/PFE/dataDéfV11.csv')
def_v2 = pd.read_csv('/content/drive/My Drive/PFE/dataDéfV2.csv')

# %%
def_v1
# Out:
#            0         1         2         3  ...  16380  16381  16382  16383
# 0    85.0207   85.3056   85.6413   85.8244  ...    NaN    NaN    NaN    NaN
# 1    79.1562   79.5834   79.7818   80.1480  ...    NaN    NaN    NaN    NaN
# 2    86.9383   87.2587   87.7012   87.8538  ...    NaN    NaN    NaN    NaN
# 3  -100.0700 -100.0150  -99.9695  -99.9390  ...    NaN    NaN    NaN    NaN
# 4    92.8130   93.1487   93.3013   93.4539  ...    NaN    NaN    NaN    NaN
# 5   -57.5708  -57.5952  -57.5952  -57.6410  ...    NaN    NaN    NaN    NaN
# 6    95.9869   96.4904   96.7193   97.1008  ...    NaN    NaN    NaN    NaN
# 7   -99.8220  -99.7101  -99.5880  -99.5270  ...    NaN    NaN    NaN    NaN
# 8   109.1100  109.5220  110.0100  110.2080  ...    NaN    NaN    NaN    NaN
# 9   121.2410  121.9270  122.1870  122.4160  ...    NaN    NaN    NaN    NaN
# 10  130.8590  131.5400  131.9520  132.5480  ...    NaN    NaN    NaN    NaN
# ...

# %%
data_sain.iloc[1].isnull().value_counts()
data_sain.shape
# Out:
# (337, 10156)

# %%
dsain_a=data_sain.iloc[0:100]
dsain_t=data_sain.iloc[100:187]
dsain_v1=data_sain.iloc[187:264]
dsain_v2=data_sain.iloc[264:338]
dsain_a.iloc[0].plot()

# %%
dsain_v2
# Out:
#             0         1         2         3  ...    10153    10154    10155  y
# 264   46.1967   46.1967   46.1967   46.2425  ...   0.0000   0.0000   0.0000  3
# 265   46.1967   46.1662   46.1967   46.1967  ...   0.0000   0.0000   0.0000  3
# 266   46.1967   46.1967   46.2425   46.1967  ...   0.0000   0.0000   0.0000  3
# 267  132.1050  131.5710  131.2810  130.6710  ...  46.2425  46.1967  46.1967  3
# 268   46.1967   46.1967   46.1967   46.1967  ...   0.0000   0.0000   0.0000  3
# ..        ...       ...       ...       ...  ...      ...      ...      ... ..
# 332   45.8305   45.8305   45.7847   45.7847  ...   0.0000   0.0000   0.0000  3
# 333   45.8610   45.8610   45.8610   45.8610  ...   0.0000   0.0000   0.0000  3
# 334   45.8305   45.8305   45.8610   45.8610  ...   0.0000   0.0000   0.0000  3
# 335   45.8305   45.8305   45.8305   45.8305  ...   0.0000   0.0000   0.0000  3
# 336   45.8305   45.8305   45.8305   45.8305  ...   0.0000   0.0000   0.0000  3
#
# ...

# %%
dsain_a = dsain_a.replace(np.nan,0)
dsain_t =dsain_t.replace(np.nan,0)
dsain_v1 = dsain_v1.replace(np.nan, 0)
dsain_v2 = dsain_v2.replace(np.nan, 0)
def_a = def_a.replace(np.nan,0)
def_t = def_t.replace(np.nan,0)
def_v1 = def_v1.replace(np.nan,0)
def_v2 = def_v2.replace(np.nan,0)

# %%
data_sain = data_sain.replace(np.nan, 0)
def_a = def_a.replace(np.nan,0)
def_t = def_t.replace(np.nan,0)
def_v1 = def_v1.replace(np.nan,0)
def_v2 = def_v2.replace(np.nan,0)

# %%
dsain_v
# Out:
# 2

# %%
dsain_a['y']=0
dsain_t['y']=1
dsain_v1['y'] = 2
dsain_v2['y'] = 4
def_a['y'] = 5
def_t['y'] = 6
def_v1['y'] = 7
def_v2['y'] = 8

train = pd.DataFrame()
train=dsain_a.append(dsain_t)
train = train.append(dsain_v1)
train = train.append(dsain_v2)
train=train.append(def_a)
train=train.append(def_t)
train = train.append(def_v1)
train = train.append(def_v2)

# %%
data_sain['y']=0
def_a['y'] = 1
def_t['y'] = 2
def_v1['y'] = 3
def_v2['y'] = 4

train = pd.DataFrame()
train=data_sain.append(def_a)
train=train.append(def_t)
train = train.append(def_v1)
train = train.append(def_v2)

# %%
x = pd.DataFrame()
y = pd.DataFrame()
y = train['y']
x = train.drop(['y'], axis = 1)

# %%
x.shape
# Out:
# (526, 16384)

# %%
x.isnull().any()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16379     True
# 16380     True
# 16381     True
# 16382     True
# 16383     True
# Length: 16384, dtype: bool

# %%
from numpy import array
import math
import random
import matplotlib.pyplot as plt
import csv
import numpy as np
from keras.models import Sequential
from keras.layers import Flatten
from keras.layers import Dense

# %%
x = x.replace(np.nan,0)

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
x = pd.DataFrame(x_scaled)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=21)

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Columns: 16384 entries, 0 to 16383
# dtypes: float64(16384)
# memory usage: 65.8 MB

# %% [markdown]
# # neural network

# %%
from keras.layers.core import Dense, Dropout, Activation

# %%
model = Sequential()
model.add(Dense(6, input_dim=6,  input_shape=(16384,) ))
model.add(Activation('relu'))
model.add(Dropout(0.1))


model.add(Dense(20, name="layer2"))
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Dense(40, name="layer3"))
model.add(Activation('relu'))
model.add(Dropout(0.1))

model.add(Dense(6, activation='softmax'))

# %%
import tensorflow as tf

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#model.compile(loss='mean_squared_error', optimizer = SGD(learning_rate=0.01, momentum=0.9), metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(x, y, epochs=150, batch_size=32, verbose=2)
# evaluate on test set
#yhat = model.predict(X_test)
# Out:
# Epoch 1/150
# 14/14 - 1s - loss: 1.7242 - accuracy: 0.1514
# Epoch 2/150
# 14/14 - 0s - loss: 1.4804 - accuracy: 0.2936
# Epoch 3/150
# 14/14 - 0s - loss: 1.4227 - accuracy: 0.3876
# Epoch 4/150
# 14/14 - 0s - loss: 1.3460 - accuracy: 0.4518
# Epoch 5/150
# 14/14 - 0s - loss: 1.2798 - accuracy: 0.5092
# Epoch 6/150
# 14/14 - 0s - loss: 1.2564 - accuracy: 0.5803
# Epoch 7/150
# 14/14 - 0s - loss: 1.1621 - accuracy: 0.6170
# Epoch 8/150
# 14/14 - 0s - loss: 1.1911 - accuracy: 0.5940
# Epoch 9/150
# 14/14 - 0s - loss: 1.1243 - accuracy: 0.5917
# Epoch 10/150
# 14/14 - 0s - loss: 1.0764 - accuracy: 0.6468
# Epoch 11/150
# 14/14 - 0s - loss: 1.0491 - accuracy: 0.6468
# Epoch 12/150
# 14/14 - 0s - loss: 1.0036 - accuracy: 0.6376
# Epoch 13/150
# 14/14 - 0s - loss: 1.0074 - accuracy: 0.6445
# Epoch 14/150
# 14/14 - 0s - loss: 0.9835 - accuracy: 0.6376
# Epoch 15/150
# 14/14 - 0s - loss: 1.0331 - accuracy: 0.6147
# Epoch 16/150
# 14/14 - 0s - loss: 0.9435 - accuracy: 0.6491
# Epoch 17/150
# ...

# %%
# creation of the model and its structure
model = Sequential()

model.add(Dense(5, activation='relu',input_shape=(10000, 1)))       
model.add(Dense(3))
model.add(Dense(3))
model.add(Flatten())
model.add(Dense(8,activation = "softmax"))
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_16 (Dense)             (None, 10000, 5)          10
# _________________________________________________________________
# dense_17 (Dense)             (None, 10000, 3)          18
# _________________________________________________________________
# dense_18 (Dense)             (None, 10000, 3)          12
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 30000)             0
# _________________________________________________________________
# dense_19 (Dense)             (None, 8)                 240008
# ...
# Total params: 240,048
# Trainable params: 240,048
# Non-trainable params: 0
# _________________________________________________________________

# %%
#optimisation parameters
model.compile(optimizer='adam', loss='binary_crossentropy',metrics = ['accuracy'])

# %% [markdown]
# # Xgboost

# %%
import xgboost as xgb
model1 = xgb.XGBClassifier()
model2 = xgb.XGBClassifier(n_estimators=100, max_depth=8, learning_rate=0.1, subsample=0.5)

train_model1 = model1.fit(X_train, y_train)
train_model2 = model2.fit(X_train, y_train)
#prediction and Classification Report
from sklearn.metrics import classification_report

pred1 = train_model1.predict(X_test)
pred2 = train_model2.predict(X_test)

print('Model 1 XGboost Report %r' % (classification_report(y_test, pred1)))
print('Model 2 XGboost Report %r' % (classification_report(y_test, pred2)))
#Let's use accuracy score
from sklearn.metrics import accuracy_score

print("Accuracy for model 1: %.2f" % (accuracy_score(y_test, pred1) * 100))
print("Accuracy for model 2: %.2f" % (accuracy_score(y_test, pred2) * 100))
# Out:
# Model 1 XGboost Report '              precision    recall  f1-score   support\n\n           0       0.92      1.00      0.96        34\n           1       0.89      0.92      0.91        26\n           2       1.00      0.96      0.98        25\n           3       0.95      0.86      0.90        21\n           4       0.81      0.81      0.81        21\n           5       1.00      0.94      0.97        17\n\n    accuracy                           0.92       144\n   macro avg       0.93      0.92      0.92       144\nweighted avg       0.93      0.92      0.92       144\n'
# ...

# %%
y_test
# Out:
# 27     4
# 201    2
# 122    1
# 27     5
# 256    2
#       ..
# 27     0
# 89     0
# 46     5
# 73     0
# 69     0
# Name: y, Length: 144, dtype: int64

# %%
pred2
# Out:
# array([4, 2, 1, 5, 2, 5, 3, 1, 3, 0, 2, 4, 2, 1, 1, 2, 0, 3, 2, 3, 3, 0,
#        2, 5, 3, 3, 0, 4, 1, 1, 4, 4, 3, 1, 2, 1, 0, 4, 0, 1, 3, 5, 5, 2,
#        0, 2, 5, 2, 1, 1, 2, 0, 3, 0, 4, 2, 2, 5, 2, 2, 5, 4, 1, 3, 0, 1,
#        4, 4, 2, 2, 1, 4, 4, 0, 5, 3, 3, 2, 1, 0, 0, 0, 3, 1, 4, 2, 5, 1,
#        0, 0, 2, 0, 4, 0, 1, 2, 5, 5, 4, 1, 0, 0, 3, 2, 0, 1, 0, 0, 3, 1,
#        0, 1, 0, 0, 4, 0, 4, 0, 4, 0, 1, 1, 2, 1, 0, 4, 4, 5, 5, 0, 2, 3,
#        1, 1, 3, 1, 0, 5, 3, 0, 0, 5, 0, 0])

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier

# %%
classifier = MLPClassifier(hidden_layer_sizes=(40),
                           max_iter=300,activation = 'relu',solver='adam',random_state=1)

# %%
parameter_space = {
    'hidden_layer_sizes': [(50,25), (10,5), (30,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

# %%
from sklearn.model_selection import GridSearchCV

clf = GridSearchCV(classifier, parameter_space, n_jobs=-1, cv=3)
clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# GridSearchCV(cv=3, error_score=nan,
#              estimator=MLPClassifier(activation='relu', alpha=0.0001,
#                                      batch_size='auto', beta_1=0.9,
#                                      beta_2=0.999, early_stopping=False,
#                                      epsilon=1e-08, hidden_layer_sizes=40,
#                                      learning_rate='constant',
#                                      learning_rate_init=0.001, max_fun=15000,
#                                      max_iter=300, momentum=0.9,
#                                      n_iter_no_change=10,
#                                      nesterovs_momentum=True, power_t=0.5,
#                                      random_state=1, s...
# ...

# %%
# Best paramete set
print('Best parameters found:\n', clf.best_params_)

# All results
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (30,), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.753 (+/-0.046) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 25), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.739 (+/-0.027) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 25), 'learning_rate': 'constant', 'solver': 'adam'}
# 0.756 (+/-0.027) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 25), 'learning_rate': 'adaptive', 'solver': 'sgd'}
# 0.739 (+/-0.027) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (50, 25), 'learning_rate': 'adaptive', 'solver': 'adam'}
# 0.739 (+/-0.027) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'sgd'}
# 0.648 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.001, 'hidden_layer_sizes': (10, 5), 'learning_rate': 'constant', 'solver': 'adam'}
# ...

# %%
classifier = MLPClassifier(hidden_layer_sizes=(30,),
                           max_iter=300,activation = 'relu', solver='adam', alpha = 0.05, learning_rate='adaptive', random_state=1)

# %%
#0.813 (+/-0.119) for {'activation': 'relu', 'alpha': 0.005, 'hidden_layer_sizes': (30,), 'learning_rate': 'adaptive', 'solver': 'adam'}

# %%
classifier.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='relu', alpha=0.05, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(30,), learning_rate='adaptive',
#               learning_rate_init=0.001, max_fun=15000, max_iter=300,
#               momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#               power_t=0.5, random_state=1, shuffle=True, solver='adam',
#               tol=0.0001, validation_fraction=0.1, verbose=False,
#               warm_start=False)

# %%
y_pred = pd.DataFrame()
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
print("Accuracy for model 3: %.2f" % (accuracy_score(y_test, y_pred) * 100))
#76.44
# Out:
# Accuracy for model 3: 83.02

# %%
df = pd.DataFrame()
df['test'] = y_test
df['precit'] = y_pred
df.to_csv('dff1.csv', index=False)

# %%
def accuracy(confusion_matrix):
   diagonal_sum = confusion_matrix.trace()
   sum_of_all_elements = confusion_matrix.sum()
   return diagonal_sum / sum_of_all_elements

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_pred, y_test)
print('Accuracy of MLPClassifier : ', accuracy(cm))
# Out:
# Accuracy of MLPClassifier :  0.8301886792452831

# %%
dsain_a.iloc[0].index[dsain_a.iloc[0].apply(np.isnan)][0]
d = dsain_a.iloc[0].replace(np.nan,dsain_a.iloc[0][int(dsain_a.iloc[0].index[dsain_a.iloc[0].apply(np.isnan)][0])-1])
from matplotlib import pyplot as plt
#d=d.to_numpy()
#plt.plot(d)
#dsain_a.iloc[0].plot()
#dsain_a.iloc[0][int(dsain_a.iloc[0].index[dsain_a.iloc[0].apply(np.isnan)][0])-1]
#[int(dsain_a.iloc[0].index[dsain_a.iloc[0].apply(np.isnan)][0])]
d=pd.DataFrame(d)
d[1]=dsain_a.iloc[1]
#d.shape
df=pd.DataFrame(dsain_a)
df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-71-80766b237fec> in <module>()
# ----> 1 dsain_a.iloc[0].index[dsain_a.iloc[0].apply(np.isnan)][0]
#       2 d = dsain_a.iloc[0].replace(np.nan,dsain_a.iloc[0][int(dsain_a.iloc[0].index[dsain_a.iloc[0].apply(np.isnan)][0])-1])
#       3 from matplotlib import pyplot as plt
#       4 #d=d.to_numpy()
#       5 #plt.plot(d)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4102         if is_scalar(key):
#    4103             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4104             return getitem(key)
#    4105
#    4106         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
#for i,row in dsain_a.iterrows():
for i in range(0,99):
  if (dsain_a.iloc[i].isnull().value_counts().count()==2):
    print("la ligne",i,"ne contient pas de valeurs nan")
  else:
    print("b")
    dsain_a.iloc[i]=dsain_a.iloc[i].replace(np.nan,dsain_a.iloc[i][int(dsain_a.iloc[i].index[dsain_a.iloc[i].apply(np.isnan)][i])-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-150-19e902e936c2> in <module>()
#       4     print("la ligne",i,"ne contient pas de valeurs nan")
#       5   else:
# ----> 6     dsain_a.iloc[i]=dsain_a.iloc[i].replace(np.nan,dsain_a.iloc[i][int(dsain_a.iloc[i].index[dsain_a.iloc[i].apply(np.isnan)][i])-1])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4102         if is_scalar(key):
#    4103             key = com.cast_scalar_indexer(key, warn_float=True)
# -> 4104             return getitem(key)
#    4105
#    4106         if isinstance(key, slice):
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
i=0
#dsain_a.iloc[i][int(dsain_a.iloc[i].index[dsain_a.iloc[i].apply(np.isnan)][i])-1]
#dsain_a.iloc[i].index[dsain_a.iloc[i].apply(np.isnan)]
dsain_a.iloc[i].isna().count()==10156
#dsain_a.iloc[i].plot()
# Out:
# True

# %%
for i in range(0,99):
  if (dsain_a.iloc[i].isnull().value_counts().count()==2):
    print("la ligne",i,"ne contient pas de nan")
    dsain_a.iloc[i]=dsain_a.iloc[i].replace(np.nan,dsain_a.iloc[i][int(dsain_a.iloc[i].index[dsain_a.iloc[i].apply(np.isnan)][i])-1])
  else:
    print("b")
#d.plot()
#int(dsain_a.iloc[i].index[dsain_a.iloc[i].apply(np.isnan)][i])
#d[9520]
# Out:
# b
# a
# b
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# b
# a
# b
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# b
# a
# a
# b
# b
# a
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# a
# a
# a
# a
# ...

# %%
dsain_a.iloc[i].isnull().value_counts().count()
# Out:
# 1
